# %%
import pandas as pd
import numpy as np

df = pd.read_csv('students.csv',index_col='no')
df.sort_values('avg',ascending=False)
# Out:
#         name  kor  eng  math  total        avg  rank       sdate
# no
# 931   Jolynn   88   90   100    278  92.666667    73  2023-11-23
# 380    Raviv   84   99    95    278  92.666667    48  2024-01-11
# 448    Joela   83   99    95    277  92.333333     1  2024-08-21
# 749   Robbin   81   94    99    274  91.333333     9  2024-10-08
# 147  Riordan   95   98    80    273  91.000000    80  2024-11-05
# ..       ...  ...  ...   ...    ...        ...   ...         ...
# 728  Laurene    8   12    14     34  11.333333    11  2024-07-06
# 634     Amby   16    4    14     34  11.333333    12  2023-12-06
# 115     Fred   24    6     2     32  10.666667    24  2024-08-15
# 276    Rodie    4    3    20     27   9.000000     5  2024-05-26
# 688  Aindrea   10    4    10     24   8.000000    57  2024-10-25
#
# [1000 rows x 8 columns]

# %%
df.sort_index()
# Out:
#              name  kor  eng  math  total        avg  rank       sdate
# no
# 1     Clerkclaude   26   96    61    183  61.000000    29  2024-04-04
# 2            Elle   35   42    83    160  53.333333    54  2024-07-13
# 3         Felisha   79   31    53    163  54.333333    64  2024-10-09
# 4        Winifred   24   36    47    107  35.666667    24  2024-06-12
# 5         Zebulen   13   55    16     84  28.000000    43  2024-06-22
# ...           ...  ...  ...   ...    ...        ...   ...         ...
# 996         Jenna   12   17    44     73  24.333333    40  2024-05-09
# 997        Hebert   89   48    78    215  71.666667    98  2024-04-18
# 998        Cathee   41   21    18     80  26.666667    95  2024-07-19
# 999      Olenolin   38   72    72    182  60.666667    84  2024-10-21
# 1000       Marten   92   48    60    200  66.666667    65  2024-09-13
#
# [1000 rows x 8 columns]

# %%
df = pd.read_excel('students.xlsx',index_col='이름')
# df.sort_index()
df
# Out:
#                      학교  영어  수학  과학  사회        sw특기
# 이름
# Chucho Fibbings     구로고  54  61  78  34  Javascript
# Ignacio Piwell     디지털고  73  78  43  29           C
# Townsend Burnsell  디지털고  84  93  83  15      PYTHON
# Ivie Camings       디지털고  43  84  60  44         NaN
# Conrade Spedroni    구로고  62  97  59  88  Javascript
# ...                 ...  ..  ..  ..  ..         ...
# Starlene Kegan     디지털고  66  77  60  90           C
# Griff Linner        구로고  73  79  69  93           C
# Rickey Lenihan      구로고  36  91  66  14      PYTHON
# Fields Mortimer    디지털고  56  68  85  42         NaN
# Samaria Shann      디지털고  76  85  91  83        Java
#
# [1000 rows x 6 columns]
